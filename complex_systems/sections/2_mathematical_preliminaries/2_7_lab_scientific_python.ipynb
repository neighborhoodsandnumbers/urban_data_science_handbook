# %% [markdown]
# # Lab: Scientific Python for Dynamical Modeling
#
# Setting up a scientific Python environment; numpy, scipy, matplotlib patterns for dynamical modeling.

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
