# %% [markdown]
# # Lab: Data-Driven Methods
# Convergent cross mapping on coupled logistic maps; diffusion map embedding of high-dimensional simulation output; physics-informed neural network for a PDE system.

# %%
import numpy as np
import matplotlib.pyplot as plt
