# %% [markdown]
# # Lab: Learning Agents and Equation Discovery
#
# Q-learning agents in a simple ecology; genetic algorithm for NK landscape optimization; SINDy for equation discovery from simulation data.

# %%
import numpy as np
import matplotlib.pyplot as plt
