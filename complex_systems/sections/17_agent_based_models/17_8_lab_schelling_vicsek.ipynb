# %% [markdown]
# # Lab: Schelling and Vicsek Models in Mesa
#
# Full implementation of Schelling and Vicsek models in Mesa; systematic parameter sweeps; comparing ABM output to analytical predictions.

# %%
import numpy as np
import matplotlib.pyplot as plt
