# %% [markdown]
# # Lab: Urban Scaling, Transit Networks, and Commuting Flows
#
# Reproducing Bettencourt's urban scaling analysis; network analysis of a transit system; gravity model calibration for commuting flows.

# %%
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
