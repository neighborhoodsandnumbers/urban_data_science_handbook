# %% [markdown]
# # Lab: The Sandpile Model
# Implementing the BTW sandpile; avalanche size distributions; testing for SOC signatures in empirical data.

# %%
import numpy as np
import matplotlib.pyplot as plt
