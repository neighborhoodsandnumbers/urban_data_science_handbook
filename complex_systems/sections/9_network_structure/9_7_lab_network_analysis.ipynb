# %% [markdown]
# # Lab: Network Analysis with NetworkX
#
# Building and analyzing networks with NetworkX; computing centralities on real-world datasets; community detection with Louvain and spectral methods.

# %%
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
