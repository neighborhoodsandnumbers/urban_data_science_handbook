# %% [markdown]
# # Lab: Evolutionary Games and Fitness Landscapes
#
# Simulating replicator dynamics; evolutionary tournaments a la Axelrod; fitness landscape visualization and adaptive walks.

# %%
import numpy as np
import matplotlib.pyplot as plt
