# %% [markdown]
# # Lab: Power Law Fitting
# Fitting power laws properly with the powerlaw package; testing scaling hypotheses on city and biological data; implementing the Clauset-Shalizi-Newman procedure.

# %%
import numpy as np
import matplotlib.pyplot as plt
