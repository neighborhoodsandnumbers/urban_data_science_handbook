# %% [markdown]
# # Lab: Spatial Patterns and Interaction Models
#
# Turing pattern simulation; spatial point pattern analysis with scipy.spatial; fitting gravity and radiation models to commuting data.

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
