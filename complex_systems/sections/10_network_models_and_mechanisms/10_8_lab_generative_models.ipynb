# %% [markdown]
# # Lab: Generative Network Models
# Generating synthetic networks; fitting degree distributions (and the pitfalls of fitting power laws); comparing generative models on empirical data.

# %%
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
