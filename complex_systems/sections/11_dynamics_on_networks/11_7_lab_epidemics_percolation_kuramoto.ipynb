# %% [markdown]
# # Lab: Epidemics, Percolation, and Synchronization
#
# SIR simulation on empirical contact networks; percolation thresholds via bond/site removal; Kuramoto model on different topologies.

# %%
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
