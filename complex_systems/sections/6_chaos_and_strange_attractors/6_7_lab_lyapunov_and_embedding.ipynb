# %% [markdown]
# # Lab: Lyapunov Spectra and Attractor Reconstruction
#
# Computing Lyapunov spectra; delay-coordinate embedding of experimental data; distinguishing chaos from noise.

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
