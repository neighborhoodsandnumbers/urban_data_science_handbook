# %% [markdown]
# # Lab: Bifurcation Diagrams and Population Models
#
# Interactive bifurcation diagrams; numerically locating bifurcation points; application to population models.

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
