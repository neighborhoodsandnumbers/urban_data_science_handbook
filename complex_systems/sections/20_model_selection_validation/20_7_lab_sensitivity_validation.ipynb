# %% [markdown]
# # Lab: Sensitivity Analysis and Model Comparison
#
# Sobol sensitivity analysis on a multi-parameter model; spatial cross-validation; comparing competing models with information criteria.

# %%
import numpy as np
import matplotlib.pyplot as plt
