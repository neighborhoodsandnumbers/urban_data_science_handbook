# %% [markdown]
# # Lab: The Ising Model
# Metropolis algorithm for the 2D Ising model; measuring magnetization, susceptibility, and correlation length near criticality; finite-size scaling.

# %%
import numpy as np
import matplotlib.pyplot as plt
