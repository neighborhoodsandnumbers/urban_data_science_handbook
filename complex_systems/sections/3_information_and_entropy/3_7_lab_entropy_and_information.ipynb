# %% [markdown]
# # Lab: Entropy and Information
#
# Estimating entropy from data; mutual information as a nonlinear correlation measure; maximum entropy distributions.

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
