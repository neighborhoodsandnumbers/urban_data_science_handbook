# %% [markdown]
# # Lab: Early Warning Signals
# Detecting early warning signals in simulated and empirical time series; estimating basins of attraction via Monte Carlo.

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
