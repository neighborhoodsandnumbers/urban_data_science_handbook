# %% [markdown]
# # Descriptive Statistics

# %% [markdown]
# ## Finding the right metric

# %% [markdown]
# ## Bias
#
# Particularly geographic

# %% [markdown]
# ## Stratification

# %% [markdown]
# ## Size
#
# Show how a small, unbiased sample is better than a large, biased sample

# %% [markdown]
# ## Confidence Intervals
