# %% [markdown]
# # Data & Tooling

# %% [markdown]
# ## Python
#
# You should have familiarity with python. There are plenty of resources.
# Best resouce is probably econ books.
#
# Functions are best practice. We'll deal with some OOP in ABMs.
#
# Jupyter notebooks are the best. I prefer VS Code for file handling and overall coding ecosystem, but have worked for years in Colab, which is great for sharing results.
