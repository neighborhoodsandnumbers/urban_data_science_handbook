# %% [markdown]
# # Prediction

# %% [markdown]
# ## Handling Imbalanced Data
# (i.e. why predicting with ">99% accuracy that the next taxi to go through this intersection will not get in an accident" is not impressive)
